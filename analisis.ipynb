# %% [markdown]
# # Análisis del HotSale Argentina 2017
#
# Visualización y análisis de datos de https://ciberlunes.github.io/ventacaliente.html#
#
# Los datasets utilizados se encuentran en el repositorio
# https://github.com/ciberlunes/ciberlunes.github.io/tree/master/jsons

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
def get_and_rename(json_dataset):
    ds = pd.read_json(json_dataset)
    return ds.rename(columns={'pr': 'Descuento Real', 'pv': 'Descuento promocionado', 'or': 'Precio anterior', 'cm': 'Precio con promoción', 's': 'Supuesto precio anterior'})

# %% [markdown]
# ## Musimundo

# %%
musimundo = get_and_rename('https://raw.githubusercontent.com/ciberlunes/ciberlunes.github.io/master/jsons/hs_mm_17.json')
fravega = get_and_rename('https://github.com/ciberlunes/ciberlunes.github.io/raw/master/jsons/hs_fv_17.json')
compumundo = get_and_rename('https://raw.githubusercontent.com/ciberlunes/ciberlunes.github.io/master/jsons/hs_cpm_17.json')
garbarino = get_and_rename('https://github.com/ciberlunes/ciberlunes.github.io/raw/master/jsons/hs_gb_17.json')

# %%
ax = sns.distplot(musimundo['Descuento Real'])
ax.legend = 'real'

ax = sns.distplot(musimundo['Descuento promocionado'], axlabel='descuento real', color='red', ax=ax)
ax.legend = 'promocionado'
ax.set_title('Distribucion de descuentos real (azul) vs promocionado (rojo) en Musimundo')
ax.set_xlabel('')

# %%
sns.pairplot(musimundo)

# %%
ax = sns.pairplot(musimundo, vars=['Descuento promocionado', 'Descuento Real'], 
                  hue='Precio anterior', size=5, palette='viridis_r', grid_kws={'despine': True})

# %%
ax.square_grid
# Out:
# True

# %% [markdown]
# ## Compumundo

# %%
compumundo = get_and_rename('https://raw.githubusercontent.com/ciberlunes/ciberlunes.github.io/master/jsons/hs_cpm_17.json')
sns.pairplot(compumundo)

# %%
ax = sns.distplot(compumundo['Descuento Real'])
ax = sns.distplot(compumundo['Descuento promocionado'], color='red', ax=ax)
ax.set_title('Distribucion de descuentos real (azul) vs promocionado (rojo) en Compumundo')
ax.set_xlabel('')

# %%
sns.pairplot(compumundo, vars=['Descuento promocionado', 'Descuento Real'], 
             hue='Precio anterior', size=5, palette='viridis_r')

# %%
sns.pairplot(compumundo, vars=['Descuento Real', 'Descuento promocionado'], 
             hue='Precio anterior', size=5, palette='viridis_r')

# %% [markdown]
# ## Fravega

# %%
fravega = get_and_rename('https://github.com/ciberlunes/ciberlunes.github.io/raw/master/jsons/hs_fv_17.json')
sns.pairplot(fravega)

# %%
ax = sns.distplot(fravega['Descuento Real'])
ax = sns.distplot(fravega['Descuento promocionado'], color='red', ax=ax)
ax.set_title('Distribucion de descuentos real (azul) vs promocionado (rojo) en Fravega')
ax.set_xlabel('')

# %%
sns.pairplot(fravega,  vars=['Descuento promocionado', 'Descuento Real'], 
             hue='Precio anterior', size=5, palette='viridis_r')

# %%
ax = sns.distplot(fravega['Descuento Real'])
ax = sns.distplot(fravega['Descuento promocionado'], color='red', ax=ax)
ax.set_title('Distribucion de descuentos real (azul) vs promocionado (rojo) en Frávega')
ax.set_xlabel('')

# %% [markdown]
# ## Garbarino

# %%
garbarino = get_and_rename('https://github.com/ciberlunes/ciberlunes.github.io/raw/master/jsons/hs_gb_17.json')
sns.pairplot(garbarino)

# %%
sns.pairplot(garbarino,  vars=['Descuento promocionado', 'Descuento Real'], 
             hue='Precio anterior', size=5, palette='viridis_r')
# Out:
# Exception ignored in: <function WeakValueDictionary.__init__.<locals>.remove at 0x7fcba0e0e510>
# Traceback (most recent call last):
#   File "/home/tin/.virtualenvs/jotsail-plots/lib/python3.6/weakref.py", line 109, in remove
#     def remove(wr, selfref=ref(self), _atomic_removal=_remove_dead_weakref):
# KeyboardInterrupt

# %%
ax = sns.distplot(garbarino['Descuento Real'])
ax = sns.distplot(garbarino['Descuento promocionado'], color='red', ax=ax)
ax.set_title('Distribucion de descuentos real (azul) vs promocionado (rojo) en Garbarino')
ax.set_xlabel('')
